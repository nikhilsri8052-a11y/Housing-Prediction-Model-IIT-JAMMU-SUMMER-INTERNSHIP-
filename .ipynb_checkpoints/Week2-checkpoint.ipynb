# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from ipywidgets import Dropdown, FloatSlider, IntSlider, interact
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import make_pipeline
"""
pandas: used for loading, cleaning, transforming, and analyzing structured data with Dataframes and Series.

seaborn: High-level statistical data visualization library built on top of Matplotlib, for attractive and interactive plot.

matplotlib.pyplot: core plotting library in Python, for creating custom static, animated and interactive visualizations.

ipywidgets: Provides interactive UI controls (slider, dropdown, buttons) for jupyter notebooks to explore data dynamiclly.

scikitlearn (sklearn): Machine learning library offering tools for preprocessing, model building, evaluation and model selection.
"""
# Out:
# '\npandas: used for loading, cleaning, transforming, and analyzing structured data with Dataframes and Series.\n\nseaborn: High-level statistical data visualization library built on top of Matplotlib, for attractive and interactive plot.\n\nmatplotlib.pyplot: core plotting library in Python, for creating custom static, animated and interactive visualizations.\n\nipywidgets: Provides interactive UI controls (slider, dropdown, buttons) for jupyter notebooks to explore data dynamiclly.\n\nscikitlearn (sklearn): Machine learning library offering tools for preprocessing, model building, evaluation and model selection.\n'

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("/content/Bengaluru_House_Data.csv")
#
# File ~\anaconda3\envs\housing_env\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\housing_env\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\anaconda3\envs\housing_env\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\housing_env\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\anaconda3\envs\housing_env\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Bengaluru_House_Data.csv'

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.info() #for analyzing the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df["availability"].value_counts() #which value appears how many times in that column
# Out:
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 16-Oct               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64

# %%
"""
Correlation: how much one column is depended on the other column.
### measures the strength and of the relationship between two variables in a dataset.

select_dtype(): selects based on the data types
"""

corr = df.select_dtypes("number").corr()
sns.heatmap(corr) #seaborn is a lib that help us create heatmaps

"""
1. the more dark it is the lessor the corr.
2. we dont want to use the entire corr.
3. we only keep the prominant one and remove the other, this help us to reduce the data and make the process easier.
4. here we can see the lighter, the more corr.
5. center is completly white because its the same corr.
6. here we have taken corr of all numberical values.
"""
# Out:
# '\n1. the more dark it is the lessor the corr.\n2. we dont want to use the entire corr.\n3. we only keep the prominant one and remove the other, this help us to reduce the data and make the process easier.\n4. here we can see the lighter, the more corr.\n5. center is completly white because its the same corr.\n6. here we have taken corr of all numberical values.\n'

# %%
"""
calculate null values
"""
df.isnull().sum()
#is null tells true or false, with .sum(), we added all the null values
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df1 = df.drop(columns = ['area_type', 'society', 'balcony', 'availability'])
"""
df1 is a new dataframe as we dont want to delete columns from original dataframe.
"""
# Out:
# '\ndf1 is a new dataframe as we dont want to delete columns from original dataframe.\n'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
df1.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
"""
Droping null values
"""
df1.dropna(inplace = True)

# %%
df1.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
"""
to get the unique values of the column
"""
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1['bedrooms'] = df1['size'].apply(lambda x: int(x.split(' ')[0]))

# .apply() -> a way of applying a function in that column.

# %%
df1.head()
# Out:
#                    location       size total_sqft  bath   price  bedrooms
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07         2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00         4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00         3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00         3
# 4                  Kothanur      2 BHK       1200   2.0   51.00         2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13246 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   size        13246 non-null  object
#  2   total_sqft  13246 non-null  object
#  3   bath        13246 non-null  float64
#  4   price       13246 non-null  float64
#  5   bedrooms    13246 non-null  int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 724.4+ KB

# %%
df1 = df1.drop(columns = ['size'])

# %%
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13246 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   total_sqft  13246 non-null  object
#  2   bath        13246 non-null  float64
#  3   price       13246 non-null  float64
#  4   bedrooms    13246 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 620.9+ KB
#                    location total_sqft  bath   price  bedrooms
# 0  Electronic City Phase II       1056   2.0   39.07         2
# 1          Chikka Tirupathi       2600   5.0  120.00         4
# 2               Uttarahalli       1440   2.0   62.00         3
# 3        Lingadheeranahalli       1521   3.0   95.00         3
# 4                  Kothanur       1200   2.0   51.00         2

# %%
"""
We are doing to drop the values of the bedrooms which are very rare.
like, 40 bhk and etc.
these values are out lyers
"""
df1['bedrooms'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
df1[df1.bedrooms > 20]
#here we can see only 2 values.
# Out:
#                        location total_sqft  bath  price  bedrooms
# 1718  2Electronic City Phase II       8000  27.0  230.0        27
# 4684                Munnekollal       2400  40.0  660.0        43

# %%
"""
Now we will check what types of values in total square foot
total_sqft is a object
"""
df1['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
#this fuction checks weather a value is converatble to float or not

def is_float(x):
  try:
    float(x)
  except:
    return False
  return True

# %%
df1[~df1['total_sqft'].apply(is_float)].head(10)
#this line checks top 10 value that cannot be converted to float
# Out:
#                location      total_sqft  bath    price  bedrooms
# 30            Yelahanka     2100 - 2850   4.0  186.000         4
# 122              Hebbal     3067 - 8156   4.0  477.000         4
# 137  8th Phase JP Nagar     1042 - 1105   2.0   54.005         2
# 165            Sarjapur     1145 - 1340   2.0   43.490         2
# 188            KR Puram     1015 - 1540   2.0   56.800         2
# 410             Kengeri  34.46Sq. Meter   1.0   18.500         1
# 549         Hennur Road     1195 - 1440   2.0   63.770         2
# 648             Arekere       4125Perch   9.0  265.000         9
# 661           Yelahanka     1120 - 1145   2.0   48.130         2
# 672        Bettahalsoor     3090 - 5002   4.0  445.000         4

# %%
def convert_sqrt_to_num(x):
  if isinstance(x, float): #isinstance, to do operations on the current hold value of x
    return x
  tokens = x.split('-')
  if len(tokens) == 2:
    return (float(tokens[0]) + float(tokens[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df4 = df1.copy()
df4['total_sqft'] = df4['total_sqft'].apply(convert_sqrt_to_num)
df4.dropna(inplace = True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13200 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13200 non-null  object
#  1   total_sqft  13200 non-null  float64
#  2   bath        13200 non-null  float64
#  3   price       13200 non-null  float64
#  4   bedrooms    13200 non-null  int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 618.8+ KB

# %%
df4.head()
# Out:
#                    location  total_sqft  bath   price  bedrooms
# 0  Electronic City Phase II      1056.0   2.0   39.07         2
# 1          Chikka Tirupathi      2600.0   5.0  120.00         4
# 2               Uttarahalli      1440.0   2.0   62.00         3
# 3        Lingadheeranahalli      1521.0   3.0   95.00         3
# 4                  Kothanur      1200.0   2.0   51.00         2

# %%
"""
Outliers: 1. finding the anomoly
1. they dont follow the general pattern of the data.
2. they can scew the data.
3. it can distort the stats.
4. we use IQR(inter quartile range) to remove them.
5. its important to remove to improve the quality of the model.

### BOX Plot:
1. wisker plot, use break our data into the quartile range.

Orange line inside the box → Median (50th percentile), the middle value of the data.
Box → Contains the middle 50% of the data (from Q1 to Q3).
Lower whisker → Smallest value that is not considered an outlier.
Upper whisker → Largest value that is not considered an outlier.
Circles above and below → Outliers (unusually large or small values).
"""
plt.boxplot(df4['total_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8e3d3800>,
#   <matplotlib.lines.Line2D at 0x7add8e3d3ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add8e3d3d10>,
#   <matplotlib.lines.Line2D at 0x7add8e424050>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8e3d1ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add8e424230>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add8e424530>],
#  'means': []}

# %%
df4['total_sqft'].describe()
# Out:
# count    13200.000000
# mean      1555.302783
# std       1237.323445
# min          1.000000
# 25%       1100.000000
# 50%       1275.000000
# 75%       1672.000000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %%
"""
Now we have to create mask
"""
low, high = df4['total_sqft'].quantile([0.1, 0.9]) #taking 10 and 90 percent as the quartile
mask_area = df4['total_sqft'].between(low, high)
df4 = df4[mask_area]

# %%
plt.boxplot(df4['total_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8e3b2c30>,
#   <matplotlib.lines.Line2D at 0x7add8e3b2f30>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add8e3b3200>,
#   <matplotlib.lines.Line2D at 0x7add8e3b3500>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8e3b29c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add8e3b3800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add8e3b3aa0>],
#  'means': []}

# %%
plt.boxplot(df4['bath'])
### Plotting for bathrooms
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8e7b34a0>,
#   <matplotlib.lines.Line2D at 0x7add8e7b3770>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add8e7b3a70>,
#   <matplotlib.lines.Line2D at 0x7add8e7b3d40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8e7b31a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add8e7f8050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add8e7f81a0>],
#  'means': []}

# %%
df4['bath'].describe()
# Out:
# count    10594.000000
# mean         2.556069
# std          1.088512
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         40.000000
# Name: bath, dtype: float64

# %%
df4 = df4[df4['bath'] < 12]

# %%
plt.boxplot(df4['bath'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8e82bb60>,
#   <matplotlib.lines.Line2D at 0x7add8e82be60>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add8e8541a0>,
#   <matplotlib.lines.Line2D at 0x7add8e8544a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8e82b860>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add8e8547a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add8e854a40>],
#  'means': []}

# %%
df4['bath'].value_counts()
# Out:
# bath
# 2.0     6468
# 3.0     2933
# 4.0      632
# 5.0      190
# 1.0      135
# 6.0      117
# 7.0       46
# 8.0       31
# 9.0       22
# 10.0       9
# 11.0       3
# Name: count, dtype: int64

# %%
df4['price_per_sqft'] = df4['price'] * 100000 / df4['total_sqft']
#this line creates a new column that is dependent on the other column.

# %%
df4.head()
# Out:
#                    location  total_sqft  bath  price  bedrooms  price_per_sqft
# 0  Electronic City Phase II      1056.0   2.0  39.07         2     3699.810606
# 2               Uttarahalli      1440.0   2.0  62.00         3     4305.555556
# 3        Lingadheeranahalli      1521.0   3.0  95.00         3     6245.890861
# 4                  Kothanur      1200.0   2.0  51.00         2     4250.000000
# 5                Whitefield      1170.0   2.0  38.00         2     3247.863248

# %%
df4['price_per_sqft'].describe()
# Out:
# count    10586.000000
# mean      6244.315309
# std       3698.326765
# min        500.000000
# 25%       4206.709513
# 50%       5252.421226
# 75%       6761.335502
# max      53150.000000
# Name: price_per_sqft, dtype: float64

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10586 entries, 0 to 13317
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        10586 non-null  object
#  1   total_sqft      10586 non-null  float64
#  2   bath            10586 non-null  float64
#  3   price           10586 non-null  float64
#  4   bedrooms        10586 non-null  int64
#  5   price_per_sqft  10586 non-null  float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 578.9+ KB

# %%
plt.boxplot(df4['price_per_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8ed439e0>,
#   <matplotlib.lines.Line2D at 0x7add8ed416a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add90fb9fa0>,
#   <matplotlib.lines.Line2D at 0x7add90fba1e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8ed43f80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add90fbb920>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add90fb8410>],
#  'means': []}

# %%
low, high = df4['price_per_sqft'].quantile([0.1, 0.9])
mask_price = df4['price_per_sqft'].between(low, high)
df4 = df4[mask_price]

# %%
plt.boxplot(df4['price_per_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7add8e989700>,
#   <matplotlib.lines.Line2D at 0x7add8e98a240>],
#  'caps': [<matplotlib.lines.Line2D at 0x7add8e98ab70>,
#   <matplotlib.lines.Line2D at 0x7add8e988ec0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7add8e988dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7add8e98a870>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7add8e99a840>],
#  'means': []}

# %%
"""
converting the string to computer level
"""
df4.location = df4.location.apply(lambda x: x.strip())
location_stats = df4['location'].value_counts(ascending = False)
location_stats #stores and display the data.
# Out:
# location
# Whitefield                              355
# Sarjapur  Road                          293
# Kanakpura Road                          205
# Thanisandra                             189
# Electronic City                         167
#                                        ...
# Madiwala                                  1
# Jogupalya                                 1
# Subhash Nagar                             1
# Kengeri Satellite Town KHB Apartment      1
# Hanuman Nagar                             1
# Name: count, Length: 934, dtype: int64

# %%
location_stats_less_than_10 =  location_stats[location_stats <= 10]
len(location_stats_less_than_10)
# Out:
# 765

# %%
df4.location.nunique()
### nunique() -> number of unique values
# Out:
# 934

# %%
df4.location = df4.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
df4.location.nunique()
# Out:
# 170

# %%
df4.head()
# Out:
#                    location  total_sqft  bath  price  bedrooms  price_per_sqft
# 0  Electronic City Phase II      1056.0   2.0  39.07         2     3699.810606
# 2               Uttarahalli      1440.0   2.0  62.00         3     4305.555556
# 3        Lingadheeranahalli      1521.0   3.0  95.00         3     6245.890861
# 4                  Kothanur      1200.0   2.0  51.00         2     4250.000000
# 8              Marathahalli      1310.0   3.0  63.25         3     4828.244275

# %%
df4 = df4.drop(columns = 'price_per_sqft')

# %%
df4.head()
# Out:
#                    location  total_sqft  bath  price  bedrooms
# 0  Electronic City Phase II      1056.0   2.0  39.07         2
# 2               Uttarahalli      1440.0   2.0  62.00         3
# 3        Lingadheeranahalli      1521.0   3.0  95.00         3
# 4                  Kothanur      1200.0   2.0  51.00         2
# 8              Marathahalli      1310.0   3.0  63.25         3

# %%
# !pip install category_encoders

### the string columns are called categorial columns, so we need to convert them to binary
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.12/dist-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (26.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
from category_encoders import OneHotEncoder
### One hot encoder -> this will create a new column for each string(unique values), so one hot encoder keeps 1 for the column where the value is present, that is true.

# %%
x = df4.drop(['price'], axis = 'columns')

# %%
y = df4.price

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 10)

### Now we have to split our data into test, train.

# %%
"""
pipeline is a structured sequence that chains preprocessing steps(scaling, encoding, feature selection)
important : it ensures that the same transformation is applied during training and prediction, reducing the risk of data leakage.
"""

### LINEAR REGRESSION: it is a supervised learning algo that models relationship between input features.

model = make_pipeline(OneHotEncoder(), LinearRegression())
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('onehotencoder', OneHotEncoder(cols=['location'])),
#                 ('linearregression', LinearRegression())])

# %%
"""
LINEAR REGRESSION: plots a best fit line, our goal is to minimize the error.
"""
# Out:
# '\nLINEAR REGRESSION: plots a best fit line, our goal is to minimize the error.\n'

# %%
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred) #computes average absolute difference between the test data and the predicted data.
mae
# Out:
# 13.591634884069956

# %%
from sklearn.metrics import mean_absolute_percentage_error as mapefn

# %%
mape = mapefn(y_test, y_pred)
mape
# Out:
# 0.17664696219476128

# %%
def predict_price(input_data: dict):
  input_df = pd.DataFrame([input_data])
  return model.predict(input_df)[0]

example_house ={
    'location' : 'Whitefield',
    'total_sqft' : 1200,
    'bath' : 2,
    'bedrooms' : 2
}


print(predict_price(example_house))
# Out:
# 62.99548916417295

# %%
import pickle

with open("house_price_model.pkl", "wb") as f:
    pickle.dump(model, f)

print("Model saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pickle
#       2
#       3 with open("house_price_model.pkl", "wb") as f:
# ----> 4     pickle.dump(model, f)
#       5
#       6 print("Model saved successfully!")
#
# NameError: name 'model' is not defined
